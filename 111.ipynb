# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=np.linspace(0,10,50)
sinus=np.sin(x)
cosinus=np.cos(x)
plt.plot(x, sinus, 'r-o', x, cosinus, 'g--')
plt.show()
