# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from ipywidgets import interact

# %%
t= np.linspace(0, 2*np.pi, 1000)
X= 2*np.sin(t)-np.sin(2*t)
Y=2*np.cos(t)-np.cos(2*t)
plt.plot(X,Y, color='r')

# %%
t= np.linspace(0, 3*np.pi, 1000)
X= 3*np.sin(t)-np.sin(3*t)
Y=3*np.cos(t)-np.cos(3*t)
plt.plot(X,Y, color='b')

# %%
t= np.linspace(0, 4*np.pi, 1000)
X= 4*np.sin(t)-np.sin(4*t)
Y=4*np.cos(t)-np.cos(4*t)
plt.plot(X,Y, color='g')

# %%
t= np.linspace(0, 5*np.pi, 1000)
X= 5*np.sin(t)-np.sin(5*t)
Y=5*np.cos(t)-np.cos(5*t)
plt.plot(X,Y, color='y')

# %%
t= np.linspace(0, 6*np.pi, 1000)
X= 6*np.sin(t)-np.sin(6*t)
Y=6*np.cos(t)-np.cos(6*t)
plt.plot(X,Y, color='black')

# %%
t= np.linspace(0, 7*np.pi, 1000)
X= 7*np.sin(t)-np.sin(7*t)
Y=7*np.cos(t)-np.cos(7*t)
plt.plot(X,Y, color='chocolate')

# %%
t= np.linspace(0, 8*np.pi, 1000)
X= 8*np.sin(t)-np.sin(8*t)
Y=8*np.cos(t)-np.cos(8*t)
plt.plot(X,Y, color='purple')

# %%
t= np.linspace(0, 9*np.pi, 1000)
X= 9*np.sin(t)-np.sin(9*t)
Y=9*np.cos(t)-np.cos(9*t)
plt.plot(X,Y, color='green')
