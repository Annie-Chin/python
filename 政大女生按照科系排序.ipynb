# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('http://stats.moe.gov.tw/files/detail/107/107_students.csv')

# %%
nccu=df[df.學校代碼==1]
學士=nccu[nccu.等級別=='B 學士']

# %%
學士.sort_values(by='一年級女生', ascending=False, inplace=True)
# Out:
# /Users/anniechin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
學士
# Out:
#      學校代碼    學校名稱      科系代碼            科系名稱 日間∕進修別   等級別  一年級男生  一年級女生  二年級男生  \
# 82      1  國立政治大學  03211056     傳播學院大一大二不分系    D 日  B 學士     59    151     52
# 122     1  國立政治大學  04211073            法律學系    D 日  B 學士     72     82     75
# 107     1  國立政治大學  04131060          企業管理學系    D 日  B 學士     30     65     44
# 92      1  國立政治大學  04111059            會計學系    D 日  B 學士     29     62     47
# 118     1  國立政治大學  04141067       國際經營與貿易學系    D 日  B 學士     29     56     39
# 101     1  國立政治大學  04122070            財政學系    D 日  B 學士     39     48     35
# 73      1  國立政治大學  03143043            地政學系    D 日  B 學士     81     46     60
# 37      1  國立政治大學  02322008           中國文學系    D 日  B 學士     38     46     27
# 29      1  國立政治大學  02311016          歐洲語文學系    D 日  B 學士     11     46     12
# 53      1  國立政治大學  03122045            外交學系    D 日  B 學士     20     42     17
# 45      1  國立政治大學  03111024            經濟學系    D 日  B 學士     41     42     53
# ...

# %%
print(學士.iloc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-023a26839a59> in <module>
# ----> 1 plt.plot['一年級女生']
#
# TypeError: 'function' object is not subscriptable
