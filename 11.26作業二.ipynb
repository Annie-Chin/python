# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### 骰子是一點的機率

# %%
results = []

for num_throws in range(1,1001):
    throws = np.random.randint(low=1, high=7, size= num_throws)
    mask= (throws==1)
    probability_of_throws=len(throws[mask])/num_throws
    results.append(probability_of_throws)

# %%
df=pd.DataFrame({'throws':results})

df.plot(color='r')
plt.title('Law of Large Numbers')
# Out:
# Text(0.5, 1.0, 'Law of Large Numbers')
